# %%
import pandas as pd
from autogluon_benchmark.evaluation.evaluate_results import evaluate

# %%
# Replace this with the path to your CSV file
path_to_combined_csv = "results/full_results.csv"

# %%
def framework_name(row):
    """Get a unique framework name from the configuration."""
    if row.framework == "AutoGluon_bestquality":
        if row.constraint == "10m16c":
            return "AutoGluon_10m"
        elif row.constraint == "1h16c":
            return "AutoGluon_1h"
        if row.metric == "neg_wql":
            return "AutoGluon_wql"
        elif row.metric == "neg_mase":
            return "AutoGluon_mase"
    return row.framework

# %%
results = pd.read_csv(path_to_combined_csv)
results["framework"] = results.apply(framework_name, axis=1)
results["time_total_s"] = results["training_duration"] + results["predict_duration"]
results.rename(columns={"task": "dataset", "training_duration": "time_train_s", "predict_duration": "time_infer_s"}, inplace=True)

# %%
results_avg = results.groupby(["dataset", "framework"], as_index=False).mean(numeric_only=True)
results_avg["problem_type"] = "timeseries"

# %% [markdown]
# ## Aggregated results (Tables 3 & 4)

# %%
results_mase = results_avg.copy()
results_mase["metric_error"] = results_avg["mase"]

results_wql = results_avg.copy()
results_wql["metric_error"] = results_avg["wql"]

baselines = ["AutoARIMA", "AutoETS", "AutoTheta", "StatEnsemble", "DeepAR", "TFT"]

# %%
# Table 3
table_mase = evaluate(
    results_mase, 
    frameworks=["AutoGluon_mase", "AutoPyTorch"] + baselines,
    frameworks_compare_vs_all=["AutoGluon_mase"],
)[4]
# Out:
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_mase
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#         framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_mase   1850.643161      1.522474  0.027980       0.062895                    NaN  1.965517            19             4             2             4            0
# 1    StatEnsemble      0.000000      1.729490  0.083402       0.247831                    NaN  3.153846             3            10             3            10            3
# 2     AutoPyTorch  14416.636552      1.590210  0.089404       0.264912                    NaN  3.931034             2             5             4            18            0
# 3          DeepAR    357.838750      1.768584  0.126186       0.406921                    NaN  4.750000             2             3             3            20            1
# 4         AutoETS      0.000000      1.708721  0.134149       0.457442                    NaN  4.758621             1             2             6            20            0
# 5       AutoTheta      0.000000      1.860990  0.144450       0.455518                    NaN  4.962963             0             1             8            18            2
# 6             TFT    478.015172      1.807020  0.169275       0.600085                    NaN  5.758621             1             2             3            23            0
# 7       AutoARIMA      0.000000      1.894198  0.159046       0.624107                    NaN  5.923077             1             2             0            23            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#         framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_mase   1534.066067      1.638639  0.032101       0.072502                    NaN  2.08            16             3             2             4            0
# 1    StatEnsemble      0.000000      1.755936  0.081853       0.238339                    NaN  3.12             3            10             3             9            3
# 2     AutoPyTorch  14409.924000      1.704653  0.089334       0.256675                    NaN  4.12             2             3             3            17            0
# 3         AutoETS      0.000000      1.813621  0.111296       0.373594                    NaN  4.64             1             2             6            16            0
# 4       AutoTheta      0.000000      1.925144  0.137932       0.426609                    NaN  4.92             0             1             8            16            2
# 5          DeepAR    313.805000      1.884751  0.134266       0.434117                    NaN  5.08             1             2             2            20            1
# 6       AutoARIMA      0.000000      1.922403  0.156957       0.611709                    NaN  5.92             1             2             0            22            3
# 7             TFT    422.892000      1.952950  0.176979       0.635126                    NaN  6.12             1             2             1            21            0
#
# ################################################
# AutoGluon_mase VS all
#         framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_mase  0.500000  0   0  29            0.000000   1534.066067       0.072502                    NaN  2.08            19             4             2             4            0
# 1    StatEnsemble  0.230769  6  20   0           -5.206307      0.000000       0.238339                    NaN  3.12             3            10             3            10            3
# 2     AutoPyTorch  0.137931  4  25   0           -6.183659  14409.924000       0.256675                    NaN  4.12             2             5             4            18            0
# 3         AutoETS  0.137931  4  25   0          -10.586884      0.000000       0.373594                    NaN  4.64             1             2             6            20            0
# 4       AutoTheta  0.148148  4  23   0          -11.506050      0.000000       0.426609                    NaN  4.92             0             1             8            18            2
# 5          DeepAR  0.142857  4  24   0           -9.888129    313.805000       0.434117                    NaN  5.08             2             3             3            20            1
# 6       AutoARIMA  0.153846  4  22   0          -12.852066      0.000000       0.611709                    NaN  5.92             1             2             0            23            3
# 7             TFT  0.068966  2  27   0          -14.603234    422.892000       0.635126                    NaN  6.12             1             2             3            23            0

# %%
cols = ["framework", ">", "<", "=", "error_count", "rank=1_count", "rank", "loss_rescaled"]
table_mase["AutoGluon_mase"][cols].round(3).set_index("framework")
# Out:
#                 >   <   =  error_count  rank=1_count  rank  loss_rescaled
# framework
# AutoGluon_mase  0   0  29            0            19  2.08          0.073
# StatEnsemble    6  20   0            3             3  3.12          0.238
# AutoPyTorch     4  25   0            0             2  4.12          0.257
# AutoETS         4  25   0            0             1  4.64          0.374
# AutoTheta       4  23   0            2             0  4.92          0.427
# DeepAR          4  24   0            1             2  5.08          0.434
# AutoARIMA       4  22   0            3             1  5.92          0.612
# TFT             2  27   0            0             1  6.12          0.635

# %%
# Table 4
table_wql = evaluate(
    results_wql, 
    frameworks=["AutoGluon_wql"] + baselines,
    frameworks_compare_vs_all=["AutoGluon_wql"],
)[4]
# Out:
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 7 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_wql
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#        framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_wql   2075.548448  1.259648e-01  0.045834       0.074271                    NaN  1.758621            19             5             2             3            0
# 1   StatEnsemble      0.000000  1.483996e-01  0.159883       0.316876                    NaN  3.346154             0             9             6            11            3
# 2         DeepAR    357.838750  1.353100e-01  0.152098       0.418887                    NaN  3.821429             1            10             5            12            1
# 3            TFT    478.015172  1.406203e-01  0.136540       0.475977                    NaN  4.000000             5             2             7            15            0
# 4        AutoETS      0.000000  2.862962e+18  0.239177       0.559148                    NaN  4.413793             2             0             6            21            0
# 5      AutoTheta      0.000000  1.716630e-01  0.214612       0.542001                    NaN  5.000000             1             1             2            23            2
# 6      AutoARIMA      0.000000  1.633465e-01  0.194267       0.616009                    NaN  5.076923             1             2             1            22            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#        framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_wql     1740.9642      0.111622  0.051582       0.085618                    NaN  1.80            17             3             2             3            0
# 1   StatEnsemble        0.0000      0.135360  0.145075       0.329551                    NaN  3.36             0             9             5            11            3
# 2         DeepAR      313.8050      0.124559  0.163773       0.454856                    NaN  4.08             0             8             5            12            1
# 3            TFT      422.8920      0.120394  0.131884       0.487446                    NaN  4.24             4             2             4            15            0
# 4        AutoETS        0.0000      0.139676  0.183513       0.489228                    NaN  4.40             2             0             6            17            0
# 5      AutoTheta        0.0000      0.143129  0.192869       0.545361                    NaN  5.00             1             1             2            21            2
# 6      AutoARIMA        0.0000      0.150894  0.180823       0.640649                    NaN  5.12             1             2             1            21            3
#
# ################################################
# AutoGluon_wql VS all
#        framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_wql  0.500000  0   0  29            0.000000     1740.9642       0.085618                    NaN  1.80            19             5             2             3            0
# 1   StatEnsemble  0.115385  3  23   0          -11.712961        0.0000       0.329551                    NaN  3.36             0             9             6            11            3
# 2         DeepAR  0.178571  5  23   0          -11.913105      313.8050       0.454856                    NaN  4.08             1            10             5            12            1
# 3            TFT  0.172414  5  24   0           -9.341857      422.8920       0.487446                    NaN  4.24             5             2             7            15            0
# 4        AutoETS  0.103448  3  26   0          -20.417335        0.0000       0.489228                    NaN  4.40             2             0             6            21            0
# 5      AutoTheta  0.074074  2  25   0          -17.523329        0.0000       0.545361                    NaN  5.00             1             1             2            23            2
# 6      AutoARIMA  0.153846  4  22   0          -14.550020        0.0000       0.640649                    NaN  5.12             1             2             1            22            3

# %%
cols = ["framework", ">", "<", "=", "error_count", "rank=1_count", "rank", "loss_rescaled"]
table_wql["AutoGluon_wql"][cols].round(3).set_index("framework")
# Out:
#                >   <   =  error_count  rank=1_count  rank  loss_rescaled
# framework
# AutoGluon_wql  0   0  29            0            19  1.80          0.086
# StatEnsemble   3  23   0            3             0  3.36          0.330
# DeepAR         5  23   0            1             1  4.08          0.455
# TFT            5  24   0            0             5  4.24          0.487
# AutoETS        3  26   0            0             2  4.40          0.489
# AutoTheta      2  25   0            2             1  5.00          0.545
# AutoARIMA      4  22   0            3             1  5.12          0.641

# %% [markdown]
# ## Ablation studies

# %%
ablation_names = ["AutoGluon_NoDeepModels", "AutoGluon_NoStatModels", "AutoGluon_NoTreeModels", "AutoGluon_NoEnsemble", "AutoGluon_10m", "AutoGluon_1h"]

# %%
results_per_ablation = []
for abl in ablation_names + ["AutoGluon_mase"]:
    abl_results = evaluate(
        results_mase, 
        frameworks=[abl, "AutoPyTorch"] + baselines,
        frameworks_compare_vs_all=[abl],
    )[4]
    results_per_ablation.append(abl_results[abl].set_index("framework").loc[abl])
# Out:
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_NoDeepModels
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#                 framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoDeepModels    661.949253      1.568449  0.043448       0.117669                    NaN  2.241379            15             5             3             6            0
# 1            StatEnsemble      0.000000      1.729490  0.077129       0.242965                    NaN  3.192308             2            10             5             9            3
# 2             AutoPyTorch  14416.636552      1.590210  0.080063       0.241843                    NaN  3.758621             6             1             5            17            0
# 3                 AutoETS      0.000000      1.708721  0.126735       0.455857                    NaN  4.724138             1             2             6            20            0
# 4                  DeepAR    357.838750      1.768584  0.117800       0.389625                    NaN  4.750000             2             4             2            20            1
# 5               AutoTheta      0.000000      1.860990  0.136383       0.448662                    NaN  4.962963             0             2             6            19            2
# 6                     TFT    478.015172      1.807020  0.160840       0.579922                    NaN  5.620690             2             3             2            22            0
# 7               AutoARIMA      0.000000      1.894198  0.153094       0.627076                    NaN  5.961538             1             2             0            23            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#                 framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoDeepModels    498.503533      1.685638  0.046164       0.123524                    NaN  2.28            14             3             2             6            0
# 1            StatEnsemble      0.000000      1.755936  0.076214       0.235264                    NaN  3.16             2            10             5             8            3
# 2             AutoPyTorch  14409.924000      1.704653  0.082438       0.240812                    NaN  4.00             4             1             4            16            0
# 3                 AutoETS      0.000000      1.813621  0.105782       0.372413                    NaN  4.60             1             2             6            16            0
# 4               AutoTheta      0.000000      1.925144  0.132244       0.420617                    NaN  4.92             0             2             6            17            2
# 5                  DeepAR    313.805000      1.884751  0.127577       0.420200                    NaN  5.08             1             3             1            20            1
# 6               AutoARIMA      0.000000      1.922403  0.151563       0.615051                    NaN  5.96             1             2             0            22            3
# 7                     TFT    422.892000      1.952950  0.170851       0.620158                    NaN  6.00             2             2             1            20            0
#
# ################################################
# AutoGluon_NoDeepModels VS all
#                 framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoDeepModels  0.500000  0   0  29            0.000000    498.503533       0.123524                    NaN  2.28            15             5             3             6            0
# 1            StatEnsemble  0.192308  5  21   0           -3.151057      0.000000       0.235264                    NaN  3.16             2            10             5             9            3
# 2             AutoPyTorch  0.310345  9  20   0           -3.654750  14409.924000       0.240812                    NaN  4.00             6             1             5            17            0
# 3                 AutoETS  0.172414  5  24   0           -8.476733      0.000000       0.372413                    NaN  4.60             1             2             6            20            0
# 4               AutoTheta  0.148148  4  23   0           -9.350653      0.000000       0.420617                    NaN  4.92             0             2             6            19            2
# 5                  DeepAR  0.142857  4  24   0           -7.552197    313.805000       0.420200                    NaN  5.08             2             4             2            20            1
# 6               AutoARIMA  0.115385  3  23   0          -10.843458      0.000000       0.615051                    NaN  5.96             1             2             0            23            3
# 7                     TFT  0.206897  6  23   0          -12.024471    422.892000       0.620158                    NaN  6.00             2             3             2            22            0
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_NoStatModels
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#                 framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoStatModels   1533.880862      1.502266  0.031431       0.080840                    NaN  2.000000            16             8             1             4            0
# 1            StatEnsemble      0.000000      1.729490  0.082794       0.239508                    NaN  3.038462             7             5             4            10            3
# 2             AutoPyTorch  14416.636552      1.590210  0.089041       0.262370                    NaN  3.965517             2             5             4            18            0
# 3                  DeepAR    357.838750      1.768584  0.125632       0.404355                    NaN  4.714286             2             3             3            20            1
# 4                 AutoETS      0.000000      1.708721  0.133492       0.448630                    NaN  4.724138             1             2             7            19            0
# 5               AutoTheta      0.000000      1.860990  0.143765       0.451724                    NaN  4.962963             0             2             6            19            2
# 6                     TFT    478.015172      1.807020  0.168983       0.602858                    NaN  5.827586             0             2             4            23            0
# 7               AutoARIMA      0.000000      1.894198  0.158468       0.623350                    NaN  5.961538             1             2             0            23            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#                 framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoStatModels      1250.592      1.615247  0.036394       0.093690                    NaN  2.12            13             7             1             4            0
# 1            StatEnsemble         0.000      1.755936  0.081179       0.229598                    NaN  3.00             7             5             4             9            3
# 2             AutoPyTorch     14409.924      1.704653  0.089125       0.254309                    NaN  4.16             2             3             3            17            0
# 3                 AutoETS         0.000      1.813621  0.110664       0.363455                    NaN  4.60             1             2             7            15            0
# 4               AutoTheta         0.000      1.925144  0.137480       0.422450                    NaN  4.92             0             2             6            17            2
# 5                  DeepAR       313.805      1.884751  0.133843       0.430977                    NaN  5.04             1             2             2            20            1
# 6               AutoARIMA         0.000      1.922403  0.156318       0.610912                    NaN  5.96             1             2             0            22            3
# 7                     TFT       422.892      1.952950  0.176810       0.638501                    NaN  6.20             0             2             2            21            0
#
# ################################################
# AutoGluon_NoStatModels VS all
#                 framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoStatModels  0.500000  0   0  29            0.000000      1250.592       0.093690                    NaN  2.12            16             8             1             4            0
# 1            StatEnsemble  0.346154  9  17   0           -4.704285         0.000       0.229598                    NaN  3.00             7             5             4            10            3
# 2             AutoPyTorch  0.103448  3  26   0           -5.750343     14409.924       0.254309                    NaN  4.16             2             5             4            18            0
# 3                 AutoETS  0.172414  5  24   0          -10.159724         0.000       0.363455                    NaN  4.60             1             2             7            19            0
# 4               AutoTheta  0.148148  4  23   0          -10.868025         0.000       0.422450                    NaN  4.92             0             2             6            19            2
# 5                  DeepAR  0.178571  5  23   0           -9.319894       313.805       0.430977                    NaN  5.04             2             3             3            20            1
# 6               AutoARIMA  0.115385  3  23   0          -12.287176         0.000       0.610912                    NaN  5.96             1             2             0            23            3
# 7                     TFT  0.000000  0  29   0          -14.251815       422.892       0.638501                    NaN  6.20             0             2             4            23            0
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_NoTreeModels
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#                 framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoTreeModels   1619.451207      1.545126  0.029023       0.073649                    NaN  2.000000            15             8             2             4            0
# 1            StatEnsemble      0.000000      1.729490  0.069759       0.223550                    NaN  3.076923             5             8             3            10            3
# 2             AutoPyTorch  14416.636552      1.590210  0.076508       0.242441                    NaN  3.896552             3             4             4            18            0
# 3                 AutoETS      0.000000      1.708721  0.122510       0.442666                    NaN  4.758621             1             2             6            20            0
# 4                  DeepAR    357.838750      1.768584  0.113542       0.384018                    NaN  4.821429             2             3             3            20            1
# 5               AutoTheta      0.000000      1.860990  0.133993       0.439921                    NaN  4.925926             1             0             8            18            2
# 6                     TFT    478.015172      1.807020  0.159858       0.590314                    NaN  5.758621             1             2             3            23            0
# 7               AutoARIMA      0.000000      1.894198  0.145309       0.612313                    NaN  5.961538             1             2             0            23            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#                 framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoTreeModels     1319.9354      1.662894  0.032991       0.084560                    NaN  2.12            12             7             2             4            0
# 1            StatEnsemble        0.0000      1.755936  0.067778       0.213322                    NaN  3.04             5             8             3             9            3
# 2             AutoPyTorch    14409.9240      1.704653  0.076277       0.234333                    NaN  4.08             3             2             3            17            0
# 3                 AutoETS        0.0000      1.813621  0.099401       0.356677                    NaN  4.64             1             2             6            16            0
# 4               AutoTheta        0.0000      1.925144  0.127584       0.409931                    NaN  4.88             1             0             8            16            2
# 5                  DeepAR      313.8050      1.884751  0.121870       0.414149                    NaN  5.16             1             2             2            20            1
# 6               AutoARIMA        0.0000      1.922403  0.142773       0.599474                    NaN  5.96             1             2             0            22            3
# 7                     TFT      422.8920      1.952950  0.167867       0.627265                    NaN  6.12             1             2             1            21            0
#
# ################################################
# AutoGluon_NoTreeModels VS all
#                 framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_NoTreeModels  0.500000  0   0  29            0.000000     1319.9354       0.084560                    NaN  2.12            15             8             2             4            0
# 1            StatEnsemble  0.307692  8  18   0           -3.764137        0.0000       0.213322                    NaN  3.04             5             8             3            10            3
# 2             AutoPyTorch  0.172414  5  24   0           -4.797307    14409.9240       0.234333                    NaN  4.08             3             4             4            18            0
# 3                 AutoETS  0.137931  4  25   0           -9.372952        0.0000       0.356677                    NaN  4.64             1             2             6            20            0
# 4               AutoTheta  0.185185  5  22   0          -10.380234        0.0000       0.409931                    NaN  4.88             1             0             8            18            2
# 5                  DeepAR  0.071429  2  26   0           -8.567503      313.8050       0.414149                    NaN  5.16             2             3             3            20            1
# 6               AutoARIMA  0.115385  3  23   0          -11.391210        0.0000       0.599474                    NaN  5.96             1             2             0            23            3
# 7                     TFT  0.068966  2  27   0          -13.528945      422.8920       0.627265                    NaN  6.12             1             2             3            23            0
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_NoEnsemble
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#               framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0          StatEnsemble      0.000000      1.729490  0.075362       0.213819                    NaN  2.769231            10             5             2             9            3
# 1  AutoGluon_NoEnsemble   1798.349713      1.577048  0.046918       0.158922                    NaN  3.241379             7             5             4            13            0
# 2           AutoPyTorch  14416.636552      1.590210  0.080624       0.232368                    NaN  3.689655             5             2             8            14            0
# 3               AutoETS      0.000000      1.708721  0.125493       0.433892                    NaN  4.413793             1             7             3            18            0
# 4                DeepAR    357.838750      1.768584  0.118138       0.377752                    NaN  4.678571             3             2             3            20            1
# 5             AutoTheta      0.000000      1.860990  0.135551       0.429642                    NaN  4.777778             1             3             6            17            2
# 6                   TFT    478.015172      1.807020  0.160763       0.580043                    NaN  5.689655             1             3             2            23            0
# 7             AutoARIMA      0.000000      1.894198  0.152075       0.616063                    NaN  5.884615             1             2             1            22            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#               framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0          StatEnsemble      0.000000      1.755936  0.074376       0.204952                    NaN  2.72            10             5             2             8            3
# 1  AutoGluon_NoEnsemble   1500.682667      1.697095  0.053180       0.177287                    NaN  3.52             5             3             4            13            0
# 2           AutoPyTorch  14409.924000      1.704653  0.082632       0.228014                    NaN  3.88             4             1             7            13            0
# 3               AutoETS      0.000000      1.813621  0.104145       0.346734                    NaN  4.24             1             7             3            14            0
# 4             AutoTheta      0.000000      1.925144  0.130773       0.400075                    NaN  4.72             1             3             6            15            2
# 5                DeepAR    313.805000      1.884751  0.127606       0.408555                    NaN  5.00             2             1             2            20            1
# 6             AutoARIMA      0.000000      1.922403  0.150503       0.603598                    NaN  5.88             1             2             1            21            3
# 7                   TFT    422.892000      1.952950  0.170406       0.619765                    NaN  6.04             1             3             0            21            0
#
# ################################################
# AutoGluon_NoEnsemble VS all
#               framework   winrate   >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0          StatEnsemble  0.615385  16  10   0           -2.367136      0.000000       0.204952                    NaN  2.72            10             5             2             9            3
# 1  AutoGluon_NoEnsemble  0.500000   0   0  29            0.000000   1500.682667       0.177287                    NaN  3.52             7             5             4            13            0
# 2           AutoPyTorch  0.379310  11  18   0           -3.461070  14409.924000       0.228014                    NaN  3.88             5             2             8            14            0
# 3               AutoETS  0.482759  14  15   0           -7.819605      0.000000       0.346734                    NaN  4.24             1             7             3            18            0
# 4             AutoTheta  0.333333   9  18   0           -8.710992      0.000000       0.400075                    NaN  4.72             1             3             6            17            2
# 5                DeepAR  0.214286   6  22   0           -7.218310    313.805000       0.408555                    NaN  5.00             3             2             3            20            1
# 6             AutoARIMA  0.192308   5  21   0          -10.324387      0.000000       0.603598                    NaN  5.88             1             2             1            22            3
# 7                   TFT  0.137931   4  25   0          -11.959312    422.892000       0.619765                    NaN  6.04             1             3             2            23            0
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 11
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_10m
# 	datasets_framework_errors: ['m4_monthly', 'web_traffic_weekly']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#        framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_10m    358.043333      1.593257  0.036469       0.091678                    NaN  2.407407            14             5             1             7            2
# 1   StatEnsemble      0.000000      1.729490  0.079724       0.235255                    NaN  3.000000             5             8             5             8            3
# 2    AutoPyTorch  14416.636552      1.590210  0.083323       0.246973                    NaN  3.724138             4             3             6            16            0
# 3        AutoETS      0.000000      1.708721  0.128770       0.449413                    NaN  4.655172             1             4             4            20            0
# 4         DeepAR    357.838750      1.768584  0.121004       0.392417                    NaN  4.678571             3             2             3            20            1
# 5      AutoTheta      0.000000      1.860990  0.139307       0.444393                    NaN  4.814815             0             2             7            18            2
# 6            TFT    478.015172      1.807020  0.163633       0.585422                    NaN  5.689655             1             3             2            23            0
# 7      AutoARIMA      0.000000      1.894198  0.155760       0.622874                    NaN  5.846154             1             2             1            22            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 24
#        framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_10m    334.087083      1.694786  0.039508       0.099284                    NaN  2.500000            13             3             1             7            2
# 1   StatEnsemble      0.000000      1.796606  0.082201       0.236715                    NaN  3.083333             4             8             4             8            3
# 2    AutoPyTorch  14408.480833      1.740203  0.086824       0.239658                    NaN  3.875000             3             2             5            14            0
# 3        AutoETS      0.000000      1.855746  0.111989       0.374439                    NaN  4.666667             1             3             4            16            0
# 4      AutoTheta      0.000000      1.970612  0.138264       0.419862                    NaN  4.833333             0             2             7            15            2
# 5         DeepAR    316.817708      1.924407  0.130400       0.406303                    NaN  5.000000             1             2             2            19            1
# 6      AutoARIMA      0.000000      1.968655  0.159099       0.628019                    NaN  6.000000             1             2             0            21            3
# 7            TFT    421.857500      1.994867  0.174534       0.612090                    NaN  6.041667             1             2             1            20            0
#
# ################################################
# AutoGluon_10m VS all
#        framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_10m  0.500000  0   0  27            0.000000    334.087083       0.099284                    NaN  2.500000            14             5             1             7            2
# 1   StatEnsemble  0.333333  8  16   0           -4.226047      0.000000       0.236715                    NaN  3.083333             5             8             5             8            3
# 2    AutoPyTorch  0.296296  8  19   0           -5.031594  14408.480833       0.239658                    NaN  3.875000             4             3             6            16            0
# 3        AutoETS  0.185185  5  22   0           -9.330321      0.000000       0.374439                    NaN  4.666667             1             4             4            20            0
# 4      AutoTheta  0.240000  6  19   0          -10.514497      0.000000       0.419862                    NaN  4.833333             0             2             7            18            2
# 5         DeepAR  0.185185  5  22   0           -8.523324    316.817708       0.406303                    NaN  5.000000             3             2             3            20            1
# 6      AutoARIMA  0.166667  4  20   0          -12.026519      0.000000       0.628019                    NaN  6.000000             1             2             1            22            3
# 7            TFT  0.074074  2  25   0          -13.776023    421.857500       0.612090                    NaN  6.041667             1             3             2            23            0
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_1h
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#       framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_1h   1230.485920      1.516712  0.027186       0.060879                    NaN  1.931034            19             4             2             4            0
# 1  StatEnsemble      0.000000      1.729490  0.084122       0.245219                    NaN  3.153846             3            10             3            10            3
# 2   AutoPyTorch  14416.636552      1.590210  0.089818       0.265048                    NaN  3.931034             2             5             4            18            0
# 3        DeepAR    357.838750      1.768584  0.126454       0.405074                    NaN  4.750000             2             3             3            20            1
# 4       AutoETS      0.000000      1.708721  0.134267       0.455256                    NaN  4.758621             1             2             6            20            0
# 5     AutoTheta      0.000000      1.860990  0.144834       0.453248                    NaN  4.962963             0             1             8            18            2
# 6           TFT    478.015172      1.807020  0.169462       0.599605                    NaN  5.758621             1             2             3            23            0
# 7     AutoARIMA      0.000000      1.894198  0.159834       0.624007                    NaN  5.961538             1             2             0            23            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#       framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_1h   1076.777267      1.631276  0.031129       0.070097                    NaN  2.04            16             3             2             4            0
# 1  StatEnsemble      0.000000      1.755936  0.082526       0.235468                    NaN  3.12             3            10             3             9            3
# 2   AutoPyTorch  14409.924000      1.704653  0.090457       0.257840                    NaN  4.12             2             3             3            17            0
# 3       AutoETS      0.000000      1.813621  0.111984       0.371143                    NaN  4.64             1             2             6            16            0
# 4     AutoTheta      0.000000      1.925144  0.138608       0.424047                    NaN  4.92             0             1             8            16            2
# 5        DeepAR    313.805000      1.884751  0.135292       0.434292                    NaN  5.08             1             2             2            20            1
# 6     AutoARIMA      0.000000      1.922403  0.157708       0.611586                    NaN  5.96             1             2             0            22            3
# 7           TFT    422.892000      1.952950  0.177805       0.635510                    NaN  6.12             1             2             1            21            0
#
# ################################################
# AutoGluon_1h VS all
#       framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_1h  0.500000  0   0  29            0.000000   1076.777267       0.070097                    NaN  2.04            19             4             2             4            0
# 1  StatEnsemble  0.230769  6  20   0           -5.379628      0.000000       0.235468                    NaN  3.12             3            10             3            10            3
# 2   AutoPyTorch  0.137931  4  25   0           -6.306741  14409.924000       0.257840                    NaN  4.12             2             5             4            18            0
# 3       AutoETS  0.137931  4  25   0          -10.687842      0.000000       0.371143                    NaN  4.64             1             2             6            20            0
# 4     AutoTheta  0.148148  4  23   0          -11.632603      0.000000       0.424047                    NaN  4.92             0             1             8            18            2
# 5        DeepAR  0.142857  4  24   0           -9.991754    313.805000       0.434292                    NaN  5.08             2             3             3            20            1
# 6     AutoARIMA  0.115385  3  23   0          -13.048794      0.000000       0.611586                    NaN  5.96             1             2             0            23            3
# 7           TFT  0.068966  2  27   0          -14.698321    422.892000       0.635510                    NaN  6.12             1             2             3            23            0
# FOUND 7 unused columns, dropping... Unused columns: ['result', 'time_infer_s', 'models_count', 'seed', 'mase', 'wql', 'time_total_s']
# Filtering to only valid columns: ['framework', 'dataset', 'fold', 'problem_type', 'metric_error', 'time_train_s']
# Filtered to only valid frameworks: 8 frameworks
# num_datasets: 29
# num_folds: 1
# errors: 9
# ################################################
# framework: AutoARIMA
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: AutoETS
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoGluon_mase
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoPyTorch
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# framework: AutoTheta
# 	datasets_framework_errors: ['electricity_hourly', 'pedestrian_counts']
# 	datasets_framework_errors_count: 2
# 	framework_fold_errors: 2
# ################################################
# framework: DeepAR
# 	datasets_framework_errors: ['web_traffic_weekly']
# 	datasets_framework_errors_count: 1
# 	framework_fold_errors: 1
# ################################################
# framework: StatEnsemble
# 	datasets_framework_errors: ['electricity_hourly', 'kdd_cup_2018', 'pedestrian_counts']
# 	datasets_framework_errors_count: 3
# 	framework_fold_errors: 3
# ################################################
# framework: TFT
# 	datasets_framework_errors: []
# 	datasets_framework_errors_count: 0
# 	framework_fold_errors: 0
# ################################################
# all VS all
# 	All datasets regardless of failures
# valid_tasks: 29
#         framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled      rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_mase   1850.643161      1.522474  0.027980       0.062895                    NaN  1.965517            19             4             2             4            0
# 1    StatEnsemble      0.000000      1.729490  0.083402       0.247831                    NaN  3.153846             3            10             3            10            3
# 2     AutoPyTorch  14416.636552      1.590210  0.089404       0.264912                    NaN  3.931034             2             5             4            18            0
# 3          DeepAR    357.838750      1.768584  0.126186       0.406921                    NaN  4.750000             2             3             3            20            1
# 4         AutoETS      0.000000      1.708721  0.134149       0.457442                    NaN  4.758621             1             2             6            20            0
# 5       AutoTheta      0.000000      1.860990  0.144450       0.455518                    NaN  4.962963             0             1             8            18            2
# 6             TFT    478.015172      1.807020  0.169275       0.600085                    NaN  5.758621             1             2             3            23            0
# 7       AutoARIMA      0.000000      1.894198  0.159046       0.624107                    NaN  5.923077             1             2             0            23            3
#
# ################################################
# all VS all
# 	Only datasets where all frameworks succeeded
# valid_tasks: 25
#         framework  time_train_s  metric_error  bestdiff  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_mase   1534.066067      1.638639  0.032101       0.072502                    NaN  2.08            16             3             2             4            0
# 1    StatEnsemble      0.000000      1.755936  0.081853       0.238339                    NaN  3.12             3            10             3             9            3
# 2     AutoPyTorch  14409.924000      1.704653  0.089334       0.256675                    NaN  4.12             2             3             3            17            0
# 3         AutoETS      0.000000      1.813621  0.111296       0.373594                    NaN  4.64             1             2             6            16            0
# 4       AutoTheta      0.000000      1.925144  0.137932       0.426609                    NaN  4.92             0             1             8            16            2
# 5          DeepAR    313.805000      1.884751  0.134266       0.434117                    NaN  5.08             1             2             2            20            1
# 6       AutoARIMA      0.000000      1.922403  0.156957       0.611709                    NaN  5.92             1             2             0            22            3
# 7             TFT    422.892000      1.952950  0.176979       0.635126                    NaN  6.12             1             2             1            21            0
#
# ################################################
# AutoGluon_mase VS all
#         framework   winrate  >   <   =  % Less Avg. Errors  time_train_s  loss_rescaled  time_train_s_rescaled  rank  rank=1_count  rank=2_count  rank=3_count  rank>3_count  error_count
# 0  AutoGluon_mase  0.500000  0   0  29            0.000000   1534.066067       0.072502                    NaN  2.08            19             4             2             4            0
# 1    StatEnsemble  0.230769  6  20   0           -5.206307      0.000000       0.238339                    NaN  3.12             3            10             3            10            3
# 2     AutoPyTorch  0.137931  4  25   0           -6.183659  14409.924000       0.256675                    NaN  4.12             2             5             4            18            0
# 3         AutoETS  0.137931  4  25   0          -10.586884      0.000000       0.373594                    NaN  4.64             1             2             6            20            0
# 4       AutoTheta  0.148148  4  23   0          -11.506050      0.000000       0.426609                    NaN  4.92             0             1             8            18            2
# 5          DeepAR  0.142857  4  24   0           -9.888129    313.805000       0.434117                    NaN  5.08             2             3             3            20            1
# 6       AutoARIMA  0.153846  4  22   0          -12.852066      0.000000       0.611709                    NaN  5.92             1             2             0            23            3
# 7             TFT  0.068966  2  27   0          -14.603234    422.892000       0.635126                    NaN  6.12             1             2             3            23            0

# %%
abl_results = pd.DataFrame(results_per_ablation).sort_values("rank")
abl_results[["rank=1_count", "rank", "loss_rescaled"]].round(3)
# Out:
#                         rank=1_count  rank  loss_rescaled
# AutoGluon_1h                    19.0  2.04          0.070
# AutoGluon_mase                  19.0  2.08          0.073
# AutoGluon_NoStatModels          16.0  2.12          0.094
# AutoGluon_NoTreeModels          15.0  2.12          0.085
# AutoGluon_NoDeepModels          15.0  2.28          0.124
# AutoGluon_10m                   14.0  2.50          0.099
# AutoGluon_NoEnsemble             7.0  3.52          0.177

# %% [markdown]
# ## Individual results (Tables 9, 10, 11)

# %%
# Table 9
columns = ["SeasonalNaive"] + baselines + ["AutoPyTorch", "AutoGluon_mase"]
results_avg.pivot_table(index="dataset", columns="framework")["mase"][columns].round(3)
# Out:
# /tmp/ipykernel_79763/1587362944.py:3: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   results_avg.pivot_table(index="dataset", columns="framework")["mase"][columns].round(3)
# framework           SeasonalNaive  AutoARIMA  AutoETS  AutoTheta  \
# dataset
# car_parts                   1.127      1.118    1.133      1.208
# cif_2016                    1.289      1.069    0.898      1.006
# covid_deaths                8.977      6.029    5.907      7.719
# electricity_hourly          1.405        NaN    1.465        NaN
# electricity_weekly          3.037      3.009    3.076      3.113
# fred_md                     1.101      0.478    0.505      0.564
# hospital                    0.921      0.820    0.766      0.764
# kdd_cup_2018                0.975        NaN    0.988      1.010
# m1_monthly                  1.314      1.152    1.083      1.092
# m1_quarterly                2.078      1.770    1.665      1.667
# m1_yearly                   4.894      3.870    3.950      3.659
# m3_monthly                  1.146      0.934    0.867      0.855
# m3_other                    3.089      2.245    1.801      2.009
# m3_quarterly                1.425      1.419    1.121      1.119
# m3_yearly                   3.172      3.159    2.695      2.608
# m4_daily                    1.452      1.153    1.228      1.149
# m4_hourly                   1.193      1.029    1.609      2.456
# m4_monthly                  1.079      0.812    0.803      0.834
# m4_quarterly                1.602      1.276    1.167      1.183
# m4_weekly                   2.777      2.355    2.548      2.608
# m4_yearly                   3.966      3.720    3.077      3.085
# nn5_daily                   1.011      0.935    0.870      0.878
# nn5_weekly                  1.063      0.998    0.980      0.963
# pedestrian_counts           0.369        NaN    0.553        NaN
# tourism_monthly             1.631      1.585    1.529      1.666
# tourism_quarterly           1.699      1.655    1.578      1.648
# tourism_yearly              3.552      4.044    3.183      2.992
# vehicle_trips               1.302      1.427    1.301      1.284
# web_traffic_weekly          1.066      1.189    1.207      1.108
#
# framework           StatEnsemble  DeepAR    TFT  AutoPyTorch  AutoGluon_mase
# dataset
# car_parts                  1.052   0.749  0.751        0.746           0.747
# cif_2016                   0.945   1.278  1.372        1.023           1.073
# covid_deaths               5.884   7.166  5.192        4.911           5.805
# electricity_hourly           NaN   1.251  1.389        1.420           1.227
# electricity_weekly         3.077   2.447  2.861        2.322           1.892
# fred_md                    0.498   0.634  0.901        0.682           0.656
# hospital                   0.753   0.771  0.814        0.770           0.741
# kdd_cup_2018                 NaN   0.841  0.844        0.764           0.709
# m1_monthly                 1.045   1.117  1.534        1.278           1.235
# m1_quarterly               1.622   1.742  2.099        1.813           1.615
# m1_yearly                  3.769   3.674  4.318        3.407           3.371
# m3_monthly                 0.845   0.960  1.062        0.956           0.822
# m3_other                   1.769   2.061  1.926        1.871           1.837
# m3_quarterly               1.096   1.198  1.176        1.180           1.057
# m3_yearly                  2.627   2.694  2.818        2.691           2.520
# m4_daily                   1.145   1.145  1.176        1.152           1.156
# m4_hourly                  1.157   1.484  3.391        1.345           0.807
# m4_monthly                 0.780   0.933  0.947        0.851           0.782
# m4_quarterly               1.148   1.367  1.277        1.176           1.139
# m4_weekly                  2.375   2.418  2.625        2.369           2.035
# m4_yearly                  3.032   3.858  3.220        3.093           3.019
# nn5_daily                  0.859   0.812  0.789        0.807           0.761
# nn5_weekly                 0.977   0.915  0.884        0.865           0.860
# pedestrian_counts            NaN   0.309  0.373        0.354           0.312
# tourism_monthly            1.469   1.461  1.719        1.495           1.442
# tourism_quarterly          1.539   1.599  1.830        1.647           1.537
# tourism_yearly             3.231   3.476  2.916        3.004           2.946
# vehicle_trips              1.203   1.162  1.227        1.162           1.113
# web_traffic_weekly         1.068     NaN  0.973        0.962           0.938

# %%
# Table 10
columns = ["SeasonalNaive"] + baselines + ["AutoGluon_wql"]
results_avg.pivot_table(index="dataset", columns="framework")["wql"][columns].round(3)
# Out:
# /tmp/ipykernel_79763/4183787656.py:3: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   results_avg.pivot_table(index="dataset", columns="framework")["wql"][columns].round(3)
# framework           SeasonalNaive  AutoARIMA       AutoETS  AutoTheta  \
# dataset
# car_parts                   1.717      1.589  1.338000e+00      1.367
# cif_2016                    0.031      0.017  3.900000e-02      0.027
# covid_deaths                0.140      0.030  4.600000e-02      0.094
# electricity_hourly          0.108        NaN  1.000000e-01        NaN
# electricity_weekly          0.141      0.138  1.440000e-01      0.146
# fred_md                     0.104      0.056  5.000000e-02      0.057
# hospital                    0.062      0.058  5.300000e-02      0.055
# kdd_cup_2018                0.489        NaN  5.500000e-01      0.553
# m1_monthly                  0.153      0.146  1.630000e-01      0.159
# m1_quarterly                0.119      0.088  8.100000e-02      0.082
# m1_yearly                   0.184      0.160  1.390000e-01      0.137
# m3_monthly                  0.124      0.102  9.300000e-02      0.095
# m3_other                    0.047      0.035  3.200000e-02      0.035
# m3_quarterly                0.083      0.079  6.900000e-02      0.070
# m3_yearly                   0.141      0.162  1.290000e-01      0.128
# m4_daily                    0.030      0.023  2.500000e-02      0.023
# m4_hourly                   0.039      0.036  7.000000e-02      0.041
# m4_monthly                  0.109      0.085  8.500000e-02      0.088
# m4_quarterly                0.099      0.082  7.900000e-02      0.079
# m4_weekly                   0.073      0.050  5.200000e-02      0.053
# m4_yearly                   0.138      0.130  1.110000e-01      0.115
# nn5_daily                   0.292      0.169  1.620000e-01      0.188
# nn5_weekly                  0.142      0.090  8.800000e-02      0.090
# pedestrian_counts           0.675        NaN  7.640000e-01        NaN
# tourism_monthly             0.088      0.095  1.010000e-01      0.091
# tourism_quarterly           0.099      0.098  7.000000e-02      0.061
# tourism_yearly              0.170      0.156  1.570000e-01      0.176
# vehicle_trips               0.112      0.100  1.150000e-01      0.120
# web_traffic_weekly          0.936      0.475  8.302590e+19      0.503
#
# framework           StatEnsemble  DeepAR    TFT  AutoGluon_wql
# dataset
# car_parts                  1.324   0.963  0.878          0.923
# cif_2016                   0.028   0.114  0.010          0.019
# covid_deaths               0.046   0.072  0.031          0.030
# electricity_hourly           NaN   0.081  0.097          0.076
# electricity_weekly         0.141   0.123  0.118          0.088
# fred_md                    0.054   0.054  0.114          0.056
# hospital                   0.053   0.053  0.054          0.051
# kdd_cup_2018                 NaN   0.363  0.488          0.323
# m1_monthly                 0.152   0.136  0.224          0.135
# m1_quarterly               0.083   0.084  0.093          0.090
# m1_yearly                  0.142   0.142  0.127          0.134
# m3_monthly                 0.092   0.098  0.109          0.089
# m3_other                   0.031   0.036  0.033          0.031
# m3_quarterly               0.068   0.073  0.071          0.065
# m3_yearly                  0.128   0.117  0.133          0.114
# m4_daily                   0.023   0.023  0.023          0.022
# m4_hourly                  0.037   0.065  0.038          0.030
# m4_monthly                 0.082   0.092  0.089          0.081
# m4_quarterly               0.076   0.084  0.083          0.075
# m4_weekly                  0.050   0.046  0.049          0.041
# m4_yearly                  0.109   0.124  0.116          0.104
# nn5_daily                  0.164   0.148  0.145          0.140
# nn5_weekly                 0.089   0.084  0.085          0.078
# pedestrian_counts            NaN   0.230  0.261          0.238
# tourism_monthly            0.085   0.086  0.103          0.083
# tourism_quarterly          0.070   0.068  0.083          0.072
# tourism_yearly             0.155   0.141  0.102          0.152
# vehicle_trips              0.103   0.090  0.099          0.087
# web_traffic_weekly         0.474     NaN  0.223          0.225

# %%
# Table 11
columns = ["SeasonalNaive"] + baselines + ["AutoPyTorch", "AutoGluon_mase"]
(results_avg.pivot_table(index="dataset", columns="framework")["time_total_s"][columns] / 60).round(1)
# Out:
# /tmp/ipykernel_79763/4040237281.py:3: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   (results_avg.pivot_table(index="dataset", columns="framework")["time_total_s"][columns] / 60).round(1)
# framework           SeasonalNaive  AutoARIMA  AutoETS  AutoTheta  \
# dataset
# car_parts                     0.1        2.4      0.6        0.7
# cif_2016                      0.1        0.4      0.5        0.6
# covid_deaths                  0.1        1.4      0.5        0.7
# electricity_hourly            0.2        NaN     21.6        NaN
# electricity_weekly            0.2        0.3      0.4        0.5
# fred_md                       0.1        2.4      0.7        0.6
# hospital                      0.1        0.9      0.7        0.7
# kdd_cup_2018                  0.1        NaN     16.3       22.8
# m1_monthly                    0.1        1.5      0.8        0.7
# m1_quarterly                  0.1        0.3      0.5        0.7
# m1_yearly                     0.1        0.3      0.4        0.4
# m3_monthly                    0.1        4.0      1.0        0.8
# m3_other                      0.1        0.3      0.4        0.4
# m3_quarterly                  0.1        0.5      0.6        0.7
# m3_yearly                     0.1        0.4      0.5        0.4
# m4_daily                      0.2       28.5     33.0       25.3
# m4_hourly                     0.1       84.9      1.8        0.8
# m4_monthly                    0.3      296.0     37.6        7.7
# m4_quarterly                  0.2       15.7      6.2        1.6
# m4_weekly                     0.1        0.6      0.5        1.3
# m4_yearly                     0.2        4.3      0.8        0.7
# nn5_daily                     0.1        2.5      0.5        0.6
# nn5_weekly                    0.1        0.3      0.4        0.4
# pedestrian_counts             0.1        NaN      4.9        NaN
# tourism_monthly               0.1       10.2      0.8        0.7
# tourism_quarterly             0.1        0.9      0.6        0.7
# tourism_yearly                0.1        0.3      0.4        0.4
# vehicle_trips                 0.1        1.1      0.6        0.7
# web_traffic_weekly            0.2       42.3      3.7        6.2
#
# framework           StatEnsemble  DeepAR   TFT  AutoPyTorch  AutoGluon_mase
# dataset
# car_parts                    3.3     6.9   9.2        240.3            17.4
# cif_2016                     1.3     4.1   6.2        240.2            16.7
# covid_deaths                 2.3     7.9   8.8        240.4            29.3
# electricity_hourly           NaN    10.4  19.5        240.4            61.2
# electricity_weekly           1.0     3.1   6.6        240.2            14.9
# fred_md                      3.4     6.8   5.5        240.2            16.8
# hospital                     2.1     4.6   7.6        240.2            17.4
# kdd_cup_2018                 NaN    12.4  11.9        240.3            56.0
# m1_monthly                   2.7     5.5   6.2        240.2            21.6
# m1_quarterly                 1.3     5.9   5.4        240.2            15.6
# m1_yearly                    0.9     4.2   5.2        240.2            12.9
# m3_monthly                   5.8     5.1   5.9        240.3            24.2
# m3_other                     0.9     5.0   6.0        240.2            13.6
# m3_quarterly                 1.6     4.6   6.0        240.3            15.7
# m3_yearly                    1.0     5.9   5.4        240.2            12.7
# m4_daily                    82.3     6.8   8.4        240.3            68.7
# m4_hourly                   89.5     9.2  10.9        240.2            51.2
# m4_monthly                 340.3     4.9   7.9        242.0           112.1
# m4_quarterly                23.2     4.7   7.6        240.9            62.3
# m4_weekly                    2.2     5.6   7.8        240.3            20.8
# m4_yearly                    5.6     4.2   6.1        240.8            35.6
# nn5_daily                    3.3     7.3  10.9        240.3            37.4
# nn5_weekly                   1.0     3.6   6.4        240.2            13.7
# pedestrian_counts            NaN    13.5  16.7        240.7            56.4
# tourism_monthly             13.1     4.4   7.6        240.2            26.0
# tourism_quarterly            1.8     3.6   6.3        240.2            14.6
# tourism_yearly               1.0     3.5   5.8        240.3            12.4
# vehicle_trips                2.2     5.1   7.3        240.2            16.0
# web_traffic_weekly          52.8     NaN   8.3        260.5           106.0
